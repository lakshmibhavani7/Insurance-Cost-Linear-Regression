# %% [markdown]
# Good Morning, Everyone! 🌟
#
# A very warm welcome to today’s session! I hope you’re all feeling energized and ready to dive into an exciting topic.
#
# 🎉 Today, we’re going to explore Maniac Regression Hands—a fascinating concept that’s sure to spark your curiosity! 🤔✨
#
# Let’s make this session as interactive as possible—feel free to ask questions, share your thoughts, and participate actively. 🗣️💡
#
# it’s going to be both informative and fun! Let’s get started! 🚀📚

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/new_insurance_data (1).csv")

# %%
df
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 0     18.0    male  23.210       0.0     no   29087.54313                17.0
# 1     18.0    male  30.140       0.0     no   39053.67437                 7.0
# 2     18.0    male  33.330       0.0     no   39023.62759                19.0
# 3     18.0    male  33.660       0.0     no   28185.39332                11.0
# 4     18.0    male  34.100       0.0     no   14697.85941                16.0
# ...    ...     ...     ...       ...    ...           ...                 ...
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
#
# ...

# %%
df.head()
# Out:
#     age   sex    bmi  children smoker  Claim_Amount  past_consultations  \
# 0  18.0  male  23.21       0.0     no   29087.54313                17.0
# 1  18.0  male  30.14       0.0     no   39053.67437                 7.0
# 2  18.0  male  33.33       0.0     no   39023.62759                19.0
# 3  18.0  male  33.66       0.0     no   28185.39332                11.0
# 4  18.0  male  34.10       0.0     no   14697.85941                16.0
#
#    num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  \
# 0      715428.0           4720920.992                              0.0
# 1      699157.0           4329831.676                              0.0
# 2      702341.0           6884860.774                              0.0
# 3      700250.0           4274773.550                              0.0
# 4      711584.0           3787293.921                              0.0
#
#    Anual_Salary     region    charges
# 0   55784970.05  southeast  1121.8739
# ...

# %%
df.tail()
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
#
#       num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  \
# 1333     1091267.0           170380500.5                              2.0
# 1334     1107872.0           201515184.8                              2.0
# 1335     1092005.0           223644981.3                              2.0
# 1336     1106821.0           252892382.6                              3.0
# 1337     1100328.0           261631699.3                              3.0
#
#       Anual_Salary     region      charges
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              1329 non-null   float64
#  1   sex                              1338 non-null   object
#  2   bmi                              1335 non-null   float64
#  3   children                         1333 non-null   float64
#  4   smoker                           1338 non-null   object
#  5   Claim_Amount                     1324 non-null   float64
#  6   past_consultations               1332 non-null   float64
#  7   num_of_steps                     1335 non-null   float64
#  8   Hospital_expenditure             1334 non-null   float64
#  9   NUmber_of_past_hospitalizations  1336 non-null   float64
#  10  Anual_Salary                     1332 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# age                                 9
# sex                                 0
# bmi                                 3
# children                            5
# smoker                              0
# Claim_Amount                       14
# past_consultations                  6
# num_of_steps                        3
# Hospital_expenditure                4
# NUmber_of_past_hospitalizations     2
# Anual_Salary                        6
# region                              0
# charges                             0
# dtype: int64

# %% [markdown]
# EDA----exploratory data analysis
#
# data cleaning
#
# removing null
#
# removing duplicate
#
# deal with the outliers

# %%
df.isnull().sum().sum()
# Out:
# 52

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'Claim_Amount',
#        'past_consultations', 'num_of_steps', 'Hospital_expenditure',
#        'NUmber_of_past_hospitalizations', 'Anual_Salary', 'region', 'charges'],
#       dtype='object')

# %%
col = list(df.columns)

# %%
col
# Out:
# ['age',
#  'sex',
#  'bmi',
#  'children',
#  'smoker',
#  'Claim_Amount',
#  'past_consultations',
#  'num_of_steps',
#  'Hospital_expenditure',
#  'NUmber_of_past_hospitalizations',
#  'Anual_Salary',
#  'region',
#  'charges']

# %%
for i in col:
  if df[i].dtype == "object":
    df[i] = df[i].fillna(df[i].mode()[0])
  else:
    df[i]= df[i].fillna(df[i].mean())

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
#df['sex'] = df['sex'].astype(int)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#outliers
for col in df.columns:
    if df[col].dtype != 'object':
     plt.boxplot(df[col])
     plt.title(col)
     plt.show()

# %%
x = ["bmi","past_consultations","Hospital_expenditure", "NUmber_of_past_hospitalizations", "Anual_Salary"]

# %%
for i in x:
  Q1= df[i].quantile(0.25)
  Q3 = df[i].quantile(0.75)
  IQR = Q3-Q1
  lowerfence = Q1-1.5*IQR
  upperfence = Q3+ 1.5 *IQR
  df = df[(df[i] >= lowerfence) & (df[i] <= upperfence)]

# %%
for col in df.columns:
    if df[col].dtype != 'object':
     plt.boxplot(df[col])
     plt.title(col)
     plt.show()

# %%
df.to_csv("cleaneddata.csv",index = False)
print("downloded")
# Out:
# downloded

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 881 entries, 151 to 1069
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              881 non-null    float64
#  1   sex                              881 non-null    object
#  2   bmi                              881 non-null    float64
#  3   children                         881 non-null    float64
#  4   smoker                           881 non-null    object
#  5   Claim_Amount                     881 non-null    float64
#  6   past_consultations               881 non-null    float64
#  7   num_of_steps                     881 non-null    float64
#  8   Hospital_expenditure             881 non-null    float64
#  9   NUmber_of_past_hospitalizations  881 non-null    float64
#  10  Anual_Salary                     881 non-null    float64
#  11  region                           881 non-null    object
# ...

# %%
#le = LabelEncoder()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 881 entries, 151 to 1069
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              881 non-null    float64
#  1   sex                              881 non-null    object
#  2   bmi                              881 non-null    float64
#  3   children                         881 non-null    float64
#  4   smoker                           881 non-null    object
#  5   Claim_Amount                     881 non-null    float64
#  6   past_consultations               881 non-null    float64
#  7   num_of_steps                     881 non-null    float64
#  8   Hospital_expenditure             881 non-null    float64
#  9   NUmber_of_past_hospitalizations  881 non-null    float64
#  10  Anual_Salary                     881 non-null    float64
#  11  region                           881 non-null    object
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# lm = {}
# from sklearn import preprocessing
# le = preprocessing.LabelEncoder()

# for i in df.columns:
#     if df[i].dtype =="object":
#       df[i]=le.fit_transform(df[i])
#       lm[i] =dict(zip(le.classes_,le.transform(le.classes_)))
# for column, mapping in lm.items():
#   print(f"mapping for {column}: {mapping}")

# %%
lm = {}
from sklearn.preprocessing  import LabelEncoder
le = LabelEncoder()

for i in df.columns:
    if df[i].dtype =="object":
      df[i]=le.fit_transform(df[i])
      lm[i] =dict(zip(le.classes_,le.transform(le.classes_)))
for column, mapping in lm.items():
  print(f"mapping for {column}: {mapping}")
# Out:
# mapping for sex: {'female': 0, 'male': 1}
# mapping for smoker: {'no': 0, 'yes': 1}
# mapping for region: {'northeast': 0, 'northwest': 1, 'southeast': 2, 'southwest': 3}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 881 entries, 151 to 1069
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              881 non-null    float64
#  1   sex                              881 non-null    int64
#  2   bmi                              881 non-null    float64
#  3   children                         881 non-null    float64
#  4   smoker                           881 non-null    int64
#  5   Claim_Amount                     881 non-null    float64
#  6   past_consultations               881 non-null    float64
#  7   num_of_steps                     881 non-null    float64
#  8   Hospital_expenditure             881 non-null    float64
#  9   NUmber_of_past_hospitalizations  881 non-null    float64
#  10  Anual_Salary                     881 non-null    float64
#  11  region                           881 non-null    int64
# ...

# %%
#model building

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x = df.drop(columns = ["charges"]) #--- we are removing chasrges as it was target variable
y = df["charges"]

# %%
x
# Out:
#        age  sex     bmi  children  smoker  Claim_Amount  past_consultations  \
# 151   25.0    1  27.550       0.0       0   39148.95495                10.0
# 152   22.0    0  20.235       0.0       0   41547.52536                13.0
# 153   25.0    1  35.625       0.0       0   39660.60193                12.0
# 154   20.0    1  31.130       2.0       0   16032.87148                 7.0
# 155   21.0    0  17.400       1.0       0   31090.98977                21.0
# ...    ...  ...     ...       ...     ...           ...                 ...
# 1046  29.0    0  27.940       1.0       1   51168.25474                23.0
# 1048  31.0    1  25.900       3.0       1   46619.40230                27.0
# 1050  31.0    1  29.810       0.0       1   24382.58056                21.0
# 1062  43.0    0  20.045       2.0       1   21596.43846                10.0
# 1069  35.0    0  28.025       0.0       1   17200.14586                15.0
#
# ...

# %%
y
# Out:
# 151      2523.16950
# 152      2527.81865
# 153      2534.39375
# 154      2566.47070
# 155      2585.26900
#            ...
# 1046    19107.77960
# 1048    19199.94400
# 1050    19350.36890
# 1062    19798.05455
# 1069    20234.85475
# Name: charges, Length: 881, dtype: float64

# %%
# x = questions
# y= answers

# learning phase
# x-train
# y-train

# testing phase
# x-test

# after testing
# imagine the predictions are y_pred

# y-test is having actual answers

# r2 score as a teacher willcompare the y_pred and y_test

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size =0.80,random_state =42)

# %%
x_train
# Out:
#        age  sex     bmi  children  smoker  Claim_Amount  past_consultations  \
# 386   36.0    1  30.875  1.090773       0  33019.362650                13.0
# 510   44.0    1  34.320  1.000000       0  16460.954610                22.0
# 702   51.0    0  33.915  0.000000       0  52777.986870                 4.0
# 410   41.0    1  33.550  0.000000       0  10429.587600                15.0
# 927   62.0    0  33.200  0.000000       0  12491.241260                 9.0
# ...    ...  ...     ...       ...     ...           ...                 ...
# 257   26.0    1  30.875  2.000000       0  11610.725190                 5.0
# 421   35.0    1  34.320  3.000000       0  49955.291770                18.0
# 1015  19.0    0  28.310  0.000000       1  50081.810300                17.0
# 587   46.0    0  33.440  1.000000       0  27417.825300                 4.0
# 253   31.0    1  30.875  0.000000       0   8026.736902                18.0
#
# ...

# %%
y_train
# Out:
# 386      5373.36425
# 510      7147.47280
# 702      9866.30485
# 410      5699.83750
# 927     13462.52000
#            ...
# 257      3877.30425
# 421      5934.37980
# 1015    17468.98390
# 587      8240.58960
# 253      3857.75925
# Name: charges, Length: 704, dtype: float64

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
y_pred
# Out:
# array([ 7607.85080352,  5308.50427948,  9493.31042711, 11142.11548302,
#         7177.46290601,  3162.24752057, 10130.3531249 , 13303.16888518,
#         8599.14496062, 11971.4971193 , 12391.60209106, 12308.57988734,
#         6074.84855493, 15108.92969082, 13528.02651336,  7984.76016645,
#         6240.02537329,  7187.31088404,  8075.1834396 , 11911.07958654,
#         8019.95879386,  1742.29810803,  7597.0023742 ,  1759.7024501 ,
#         6684.04708442, 12676.42553721,  7366.28224082, 14058.52278458,
#        11632.69299004,  7014.33187856,  9642.68306372,  3267.35636644,
#         7828.96839265,  5055.90862348,  8297.26173924,  5815.33440369,
#         2792.33801229, 10373.99286023,  6611.11488772,  2070.84957381,
#         5819.98742891,  3574.34526225, 18529.57610284,  8941.22584014,
#        11742.74695686,  4900.04298218, 12873.02532985,  7772.21386862,
#         2975.38519267, 11871.09823443,  6261.18825847, 15106.80220452,
# ...

# %%
y_test
# Out:
# 501     6986.6970
# 405     5615.3690
# 642     8944.1151
# 843    11945.1327
# 544     7512.2670
#           ...
# 549     7624.6300
# 938    13831.1152
# 559     7731.4271
# 503     7046.7222
# 232     3537.7030
# Name: charges, Length: 177, dtype: float64

# %%
result = pd.DataFrame(columns=["Actual value","predicted value"])
result["Actual value"] = y_test
result["predicted value"] = y_pred
result
# Out:
#      Actual value  predicted value
# 501     6986.6970      7607.850804
# 405     5615.3690      5308.504279
# 642     8944.1151      9493.310427
# 843    11945.1327     11142.115483
# 544     7512.2670      7177.462906
# ..            ...              ...
# 549     7624.6300      6716.507771
# 938    13831.1152     13773.884109
# 559     7731.4271      7077.850524
# 503     7046.7222      7968.328787
# 232     3537.7030      3349.979177
#
# [177 rows x 2 columns]

# %%
from sklearn.metrics import *

# %%
result = r2_score(y_test,y_pred)

# %%
result
# Out:
# 0.9689411111502325

# %%
mae = mean_absolute_error(y_test,y_pred)
mae
# Out:
# 590.981954774146

# %%
mse = mean_squared_error(y_test,y_pred)
mse
# Out:
# 537564.6928342418

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# 733.1880337500345

# %%
sns.regplot(x =y_pred,y =y_test)
plt.xlabel("predicted charges")
plt.ylabel("actual charges")
plt.title("reg plot")
plt.show()
